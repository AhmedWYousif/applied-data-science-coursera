# %% [markdown]
# # Assignment 4
#
# Before working on this assignment please read these instructions fully. In the submission area, you will notice that you can click the link to **Preview the Grading** for each step of the assignment. This is the criteria that will be used for peer grading. Please familiarize yourself with the criteria before beginning the assignment.
#
# This assignment requires that you to find **at least** two datasets on the web which are related, and that you visualize these datasets to answer a question with the broad topic of **religious events or traditions** (see below) for the region of **Ann Arbor, Michigan, United States**, or **United States** more broadly.
#
# You can merge these datasets with data from different regions if you like! For instance, you might want to compare **Ann Arbor, Michigan, United States** to Ann Arbor, USA. In that case at least one source file must be about **Ann Arbor, Michigan, United States**.
#
# You are welcome to choose datasets at your discretion, but keep in mind **they will be shared with your peers**, so choose appropriate datasets. Sensitive, confidential, illicit, and proprietary materials are not good choices for datasets for this assignment. You are welcome to upload datasets of your own as well, and link to them using a third party repository such as github, bitbucket, pastebin, etc. Please be aware of the Coursera terms of service with respect to intellectual property.
#
# Also, you are welcome to preserve data in its original language, but for the purposes of grading you should provide english translations. You are welcome to provide multiple visuals in different languages if you would like!
#
# As this assignment is for the whole course, you must incorporate principles discussed in the first week, such as having as high data-ink ratio (Tufte) and aligning with Cairo’s principles of truth, beauty, function, and insight.
#
# Here are the assignment instructions:
#
#  * State the region and the domain category that your data sets are about (e.g., **Ann Arbor, Michigan, United States** and **religious events or traditions**).
#  * You must state a question about the domain category and region that you identified as being interesting.
#  * You must provide at least two links to available datasets. These could be links to files such as CSV or Excel files, or links to websites which might have data in tabular form, such as Wikipedia pages.
#  * You must upload an image which addresses the research question you stated. In addition to addressing the question, this visual should follow Cairo's principles of truthfulness, functionality, beauty, and insightfulness.
#  * You must contribute a short (1-2 paragraph) written justification of how your visualization addresses your stated research question.
#
# What do we mean by **religious events or traditions**?  For this category you might consider calendar events, demographic data about religion in the region and neighboring regions, participation in religious events, or how religious events relate to political events, social movements, or historical events.
#
# ## Tips
# * Wikipedia is an excellent source of data, and I strongly encourage you to explore it for new data sources.
# * Many governments run open data initiatives at the city, region, and country levels, and these are wonderful resources for localized data sources.
# * Several international agencies, such as the [United Nations](http://data.un.org/), the [World Bank](http://data.worldbank.org/), the [Global Open Data Index](http://index.okfn.org/place/) are other great places to look for data.
# * This assignment requires you to convert and clean datafiles. Check out the discussion forums for tips on how to do this from various sources, and share your successes with your fellow students!
#
# ## Example
# Looking for an example? Here's what our course assistant put together for the **Ann Arbor, MI, USA** area using **sports and athletics** as the topic. [Example Solution File](./readonly/Assignment4_example.pdf)

# %% [markdown]
# # Example
#
# ### State the region and the domain category
# United states, Health (COVID-19)
#
# ### questions about the domain category and region.
#
# - what is the highest new cases a day of covid-19 is USA and its date?
# - what is the highest day deaths a day of covid-19 is USA and its date?
# - what are top 10 infected states of covid-19 in USA?
# - what is the rank of Michigan state between states?
#
#
# ###  links of datasets
#
# https://github.com/nytimes/covid-19-data/blob/master/us.csv
#
# https://github.com/nytimes/covid-19-data/blob/master/us-states.csv
#
#
# ### Provide a short (1-2 paragraphs) justification of how your visual addresses your research question.
#
# As shown in figure 1, The highest new cases a day of covid-19 is USA is 36585 on 24/4/2020 in addition to the highest deaths a day of covid-19 is USA is 2521 on 21/4/2020.
# also we can recognize that the rapid spreading of COVID-19 started from mid of march until now.
#
# As shown in figure 2,The top 10 infected states of covid-19 in USA are from descending as following
#
# 1. New York
# 2. New Jersey
# 3. Massachusetts
# 4. Illinois
# 5. California
# 6. Pennsylvania
# 7. Michigan
# 8. Florida
# 9. Texas
# 10. Connecticut
#
# on the first position is New York with more than 300000 total infected cases on the other hand Michigan in seventh position with more than 40000 total infected cases.
#
#
# # Cairo's principle
#
#
# ##  regards to Cairo's principle of truthfulness
# I tried to avoid any misleading starting from trusted data source which is The New York Times  and through data preperation be computing new case and deaths by day instead of accumlated count then computing max values of them.
# until reaching representation phase by representing graphs that represent our phenomena of COVID-19 in US without any ambigutiy to answer our questions about this domain.
#
# e.g. I have represented COVID-19 new cases and deaths per day in whole US in figure 1 on the other hand, I represent total cases and deaths of top ten infected states in figure 2.
#
#
#
# ## regards to Cairo's principle of beauty (e.g., using fonts, colors, and layout that are appropriate and aesthetically pleasing)
# I tried to choose suitable colors for each data in the phenomena to be more representable for this prameter of the phenomena.
#
# e.g. color of new cases curve is blue because it represents our main factor on the other hand color of deaths curve is red because it represents lose factor. on other hand, the layout I remove all useless frames and details.
#
# ## regards to Cairo's principle of functionality (e.g., choosing a charting type that is appropriate for the stated research question)
# I tried to choose suitable for each data of the phenomena to answer my research questions in optimal way.
#
# e.g. I have chosen line plot graph because I represents continuous values phenomena and in same time easy to identify peak point of represented factors to answer my research questions. on the other hand, I have chosen histogram to represent top 10 infected states that is most appropriate to answer this question.
#
#
# ##  regards to Cairo's principle of insightfulness (i.e., producing a "eureka" or "aha" response in the viewer)
# I tried not replicating the data i have in the dataset, but I inference new insights that make the viewer has a full view of the phenomena
# e.g. I represented in figure 1 a full view of new cases and deaths by day, on the other hand, figure 2, I represented only relevent data to my research question and truncated all irrelevent data.

# %%
import pandas as pd
import os 
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# loading Data
df_us = pd.read_csv(f'{os.getcwd()}\\data\\us.csv')

# prepareing Data
df_us['new cases'] = df_us['cases'] - df_us['cases'].shift(fill_value=0)
df_us['new deaths'] = df_us['deaths'] - df_us['deaths'].shift(fill_value=0)
df_us['date'] = pd.to_datetime(df_us['date']).dt.strftime('%d/%m')

max_new_cases_y = df_us['new cases'].max()
max_new_deaths_y = df_us['new deaths'].max()
max_new_cases_x = df_us[df_us['new cases'] == max_new_cases_y].index[0]
max_new_deaths_x = df_us[df_us['new deaths'] == max_new_deaths_y].index[0]

# plotting cases
plt.figure(figsize=(20,10))
plt.subplot(1, 2, 1)
plt.plot(df_us.index, df_us['new cases'], c='b', label='new cases')
plt.plot(df_us.index, df_us['new deaths'], c='r', label='deaths')

#Labelling x ticks
plt.xticks(range(0, len(df_us),10), df_us.iloc[range(0, len(df_us),10)]['date'], rotation = '60')
#plt.yticks(range(0, len(df_michigan),7), pd.to_datetime(df_michigan.index[range(0, len(df_michigan),7)]), rotation = '60')

# plot points of highest
plt.plot([max_new_cases_x], [max_new_cases_y], marker='o', markersize=4, c="m", label='highest new cases')
plt.plot([max_new_deaths_x], [max_new_deaths_y], marker='o', markersize=4, c="k", label="highest deaths")

# adding labels
plt.xlabel('Day')
plt.ylabel('# cases')
plt.title("Coronavirus cases in the US on 2020")
plt.legend(frameon = False) 
plt.text(max_new_cases_x-5, max_new_cases_y+300, f'{max_new_cases_y} on {df_us.iloc[max_new_cases_x]["date"]}', c="b", fontsize=12)
plt.text(max_new_deaths_x-5, max_new_deaths_y+300, f'{max_new_deaths_y} on {df_us.iloc[max_new_deaths_x]["date"]}', c="r", fontsize=12)

# hide top and right boarder
for loc in ['top', 'right','left', 'bottom']:
    plt.gca().spines[loc].set_visible(False)



# loading states Data
df_us_states = pd.read_csv(f'{os.getcwd()}\\data\\us-states.csv')

# prepareing Data
df_us_states = df_us_states.groupby('state')['cases','deaths'].agg(cases=('cases', 'max'),  deaths=('deaths', 'max')).sort_values(by=['cases', 'deaths'], ascending=False)
top_us_states =  df_us_states[:10]


# plot barh for states
plt.subplot(1, 2, 2)
xvals = range(len(top_us_states))
plt.barh(xvals, top_us_states['deaths'], height = 0.3, color='r', label='total cases')
plt.barh([item+0.3 for item in xvals], top_us_states['cases'], height = 0.3, color='b' , label='total deaths')

#Labelling y ticks
plt.yticks(xvals,top_us_states.index, rotation = '45')

# adding labels
plt.xlabel('# cases')
plt.ylabel('States')
plt.title("Top infected covid-19 states")
plt.legend(frameon = False) 
# hide top and right boarder
for loc in ['top', 'right','left', 'bottom']:
    plt.gca().spines[loc].set_visible(False)
